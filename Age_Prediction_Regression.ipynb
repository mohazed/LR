# %% [markdown]
# # TP regression sur des images
#
# * Dans ce TP, vous mettrez en oeuvre vos connaissances en régression pour prédire l'age d'individus en fonction de leur visage.
#
# * dans la première étape du TP, vous devrez télécharger le jeu de données pour constituer les matrices X_train et Y_train (jeu d'entrainement) et X_test et Y_test (jeu de test). Ensuite, vous devrez utiliser des techniques de régression s'appuyant sur la sélection de variables, pour que le résultat soit plus interprétable
#
# ## Chargement du jeu de données.
#
# * Téléchargez [le jeu de données ici](https://www.lamsade.dauphine.fr/~ychevaleyre/data/face_age.zip). Il faut d'abord le dézipper.
# * Dans le répertoire, il y a une centaine de sous-répertoires. Dans chacun de ces sous-répertoire, vous trouvez des images d'individus dont l'age correspond à leur répertoire. Chaque image est un fichier PNG couleur de taille 200x200.
#
# * Ecrivez une fonction `chargeImage` qui prend un nom de fichier image, qui charge l'image (vous utiliserez la fonction `imread` de `matplotlib.image`) et la convertit en un tableau numpy 2D de taille 25x25. Pour cela, vous utiliserez entre autres `scipy.ndimage.interpolation.zoom(X,.125)` qui divise par 8 la taille de l'image. Il faudra aussi d'abord fusionner les 3 canaux de couleur RGB en un seul (c'est à dire faire la moyenne des trois canaux pour obtenir un seul nombre qui représente une nuance de gris).
#
# * Faites une fonction `chargeDossiers` qui utilise `chargeImage` pour charger les 30 premiers fichiers image des répertoires $5,10,15,20,25,\ldots$, et les place dans une liste. Note: pour avoir la liste de tous les noms de fichier dans le répertoire `dossier`, il faut utiliser la fonction `listdir` du package `os`. Par exemple on peut faire `listdir('/')`.
#
# ## Construction du tableau de données
#
# Maintenant que les images sont chargés, il faut pour chaque image créer un vecteur la représentant. On en peut pas directement faire une régression linéaire sur les pixels, car ceux ci ne contiennent pas assez d'information.
#
# * Créez une fonction `diffHorizontal` qui, pour une image $I$ donnée, renvoie une image $H$ telle que $H(x,y)=I(x+1,y)-I(x,y)$. Attention: en faisant cette opération, $H$ contiendra une colonne de moins que $I$. Pour que $H$ ai le même nombre de colonnes que $I$, on dupliquera la dernière colonne de $H$. Créez une fonction `diffVertical` qui, pour une image $I$ donnée, renvoie une image $V$ telle que $V(x,y)=I(x,y+1)-I(x,y)$. Idem pour la dernière ligne de $V$.
#
# * Crée une fonction `encodeImage` qui, pour une image $I1$, renvoie un tableau 1D la représentant. Voici comment ce tableau est construit. A partir de l'image $I1$ de taille 25x25, on crée les images $I2$ de taille 12x12, $I3$ de taille 6x6, $I4$ de taille 3x3. Pour chacune de ces image $Ik$, on crée les images $Hk$ et $Vk$ avec les fonctions ci-dessus. Toutes ces images sont ensuite applaties et concaténées en un grand tableau 1D.
#
# * On peut donc regrouper toutes les images dans un grand tableau 2D $X$ ou chaque ligne correspond à une image, et on crée aussi un tableau $Y$ qui correspond à l'age des images correspondantes.
#
# * Séparez ces tableau en deux, pour avoir des données d'apprentissage et des données de test. Vous n'oublierez pas de mélanger les images (les ages doivent être uniformément répartis dans les données)
#
# * Appliquez une régression linéaire classique avec la méthode matricielle vue précédemment. Calculez le score $r2$ comme vu au précédent TP, sur le jeu de test. Que pouvez vous dire du résultat ?
#
# # Sélection de variables et interprétabilité
#
# On considère comme interprétable un modèle linéaire qui s'appuie sur un petit nombre de variables.
# On utilisera pour cela deux approches:
#
#
#
# * A partir de la régression précédente,  vous sélectionnerez les 10 composantes du vecteur de paramètres les plus grands en valeur absolue. Puis, vous éliminerez des données toutes les variables qui ne correspondent pas à ces 10 paramètres. Puis, vous relancerez la régression linéaire.
#
# * Appliquez l'algorithme "matching pursuit" (voir page [wikipedia](https://en.wikipedia.org/wiki/Matching_pursuit) par exemple ) et comparez les deux.

# %% [markdown]
# # 1. Setup and Imports

# %%
# !wget https://www.lamsade.dauphine.fr/~ychevaleyre/data/face_age.zip
# !unzip face_age.zip

# Import necessary libraries
import numpy as np
import matplotlib.image as img
import scipy.ndimage as ndimage
import os
import matplotlib.pyplot as plt
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: face_age/003/7253.png
#   inflating: __MACOSX/face_age/003/._7253.png
#   inflating: face_age/003/8189.png
#   inflating: __MACOSX/face_age/003/._8189.png
#   inflating: face_age/003/5687.png
#   inflating: __MACOSX/face_age/003/._5687.png
#   inflating: face_age/003/3396.png
#   inflating: __MACOSX/face_age/003/._3396.png
#   inflating: face_age/003/7655.png
#   inflating: __MACOSX/face_age/003/._7655.png
#   inflating: face_age/003/8758.png
#   inflating: __MACOSX/face_age/003/._8758.png
#   inflating: face_age/003/1027.png
#   inflating: __MACOSX/face_age/003/._1027.png
#   inflating: face_age/003/4639.png
#   inflating: __MACOSX/face_age/003/._4639.png
#   inflating: face_age/003/4177.png
#   inflating: __MACOSX/face_age/003/._4177.png
#   inflating: face_age/003/3426.png
#   inflating: __MACOSX/face_age/003/._3426.png
#   inflating: face_age/003/1557.png
#   inflating: __MACOSX/face_age/003/._1557.png
#   inflating: face_age/003/9686.png
#   inflating: __MACOSX/face_age/003/._9686.png
#   inflating: face_age/003/7522.png
#   inflating: __MACOSX/face_age/003/._7522.png
#   inflating: face_age/003/362.png
#   inflating: __MACOSX/face_age/003/._362.png
#   inflating: face_age/003/1812.png
#   inflating: __MACOSX/face_age/003/._1812.png
#   inflating: face_age/003/9296.png
#   inflating: __MACOSX/face_age/003/._9296.png
#   inflating: face_age/003/7297.png
#   inflating: __MACOSX/face_age/003/._7297.png
#   inflating: face_age/003/8365.png
#   inflating: __MACOSX/face_age/003/._8365.png
#   inflating: face_age/003/3422.png
#   inflating: __MACOSX/face_age/003/._3422.png
#   inflating: face_age/003/6758.png
#   inflating: __MACOSX/face_age/003/._6758.png
#   inflating: face_age/003/6003.png
#   inflating: __MACOSX/face_age/003/._6003.png
#   inflating: face_age/003/7321.png
#   inflating: __MACOSX/face_age/003/._7321.png
#   inflating: face_age/003/207.png
#   inflating: __MACOSX/face_age/003/._207.png
#   inflating: face_age/003/993.png
#   inflating: __MACOSX/face_age/003/._993.png
#   inflating: face_age/003/8402.png
#   inflating: __MACOSX/face_age/003/._8402.png
#   inflating: face_age/003/417.png
#   inflating: __MACOSX/face_age/003/._417.png
#   inflating: face_age/003/8825.png
#   inflating: __MACOSX/face_age/003/._8825.png
#   inflating: face_age/003/1626.png
#   inflating: __MACOSX/face_age/003/._1626.png
#   inflating: face_age/003/2677.png
#   inflating: __MACOSX/face_age/003/._2677.png
#   inflating: face_age/003/1752.png
#   inflating: __MACOSX/face_age/003/._1752.png
#   inflating: face_age/003/2529.png
#   inflating: __MACOSX/face_age/003/._2529.png
#   inflating: face_age/003/9327.png
#   inflating: __MACOSX/face_age/003/._9327.png
#   inflating: face_age/003/6202.png
#   inflating: __MACOSX/face_age/003/._6202.png
#   inflating: face_age/003/9119.png
#   inflating: __MACOSX/face_age/003/._9119.png
#   inflating: face_age/003/8207.png
#   inflating: __MACOSX/face_age/003/._8207.png
#   inflating: face_age/003/5086.png
#   inflating: __MACOSX/face_age/003/._5086.png
#   inflating: face_age/003/2104.png
#   inflating: __MACOSX/face_age/003/._2104.png
#   inflating: face_age/003/6404.png
#   inflating: __MACOSX/face_age/003/._6404.png
#   inflating: face_age/003/9723.png
#   inflating: __MACOSX/face_age/003/._9723.png
#   inflating: face_age/003/7068.png
#   inflating: __MACOSX/face_age/003/._7068.png
#   inflating: face_age/003/1431.png
#   inflating: __MACOSX/face_age/003/._1431.png
#   inflating: face_age/003/7054.png
#   inflating: __MACOSX/face_age/003/._7054.png
#   inflating: face_age/003/7901.png
#   inflating: __MACOSX/face_age/003/._7901.png
#   inflating: face_age/003/614.png
#   inflating: __MACOSX/face_age/003/._614.png
#   inflating: face_age/003/1627.png
#   inflating: __MACOSX/face_age/003/._1627.png
#   inflating: face_age/003/5482.png
#   inflating: __MACOSX/face_age/003/._5482.png
#   inflating: face_age/003/7557.png
#   inflating: __MACOSX/face_age/003/._7557.png
#   inflating: face_age/003/840.png
#   inflating: __MACOSX/face_age/003/._840.png
#   inflating: face_age/003/5963.png
#   inflating: __MACOSX/face_age/003/._5963.png
#   inflating: face_age/003/3484.png
#   inflating: __MACOSX/face_age/003/._3484.png
#   inflating: face_age/003/2956.png
#   inflating: __MACOSX/face_age/003/._2956.png
#   inflating: face_age/003/6271.png
#   inflating: __MACOSX/face_age/003/._6271.png
#   inflating: face_age/003/3862.png
#   inflating: __MACOSX/face_age/003/._3862.png
#   inflating: face_age/003/6728.png
#   inflating: __MACOSX/face_age/003/._6728.png
#   inflating: face_age/003/538.png
#   inflating: __MACOSX/face_age/003/._538.png
#   inflating: face_age/003/8936.png
#   inflating: __MACOSX/face_age/003/._8936.png
#   inflating: face_age/003/7740.png
#   inflating: __MACOSX/face_age/003/._7740.png
#   inflating: face_age/003/8301.png
#   inflating: __MACOSX/face_age/003/._8301.png
#   inflating: face_age/003/15.png
#   inflating: __MACOSX/face_age/003/._15.png
#   inflating: face_age/003/1480.png
#   inflating: __MACOSX/face_age/003/._1480.png
#   inflating: face_age/003/3297.png
#   inflating: __MACOSX/face_age/003/._3297.png
#   inflating: face_age/003/5816.png
#   inflating: __MACOSX/face_age/003/._5816.png
#   inflating: face_age/003/2374.png
#   inflating: __MACOSX/face_age/003/._2374.png
#   inflating: face_age/003/9547.png
#   inflating: __MACOSX/face_age/003/._9547.png
#   inflating: face_age/003/316.png
#   inflating: __MACOSX/face_age/003/._316.png
#   inflating: face_age/003/8883.png
#   inflating: __MACOSX/face_age/003/._8883.png
#   inflating: face_age/003/5633.png
#   inflating: __MACOSX/face_age/003/._5633.png
#   inflating: face_age/003/1327.png
#   inflating: __MACOSX/face_age/003/._1327.png
#   inflating: face_age/003/7805.png
#   inflating: __MACOSX/face_age/003/._7805.png
#   inflating: face_age/003/5790.png
#   inflating: __MACOSX/face_age/003/._5790.png
#   inflating: face_age/003/1253.png
#   inflating: __MACOSX/face_age/003/._1253.png
#   inflating: face_age/003/6919.png
#   inflating: __MACOSX/face_age/003/._6919.png
#   inflating: face_age/003/6716.png
#   inflating: __MACOSX/face_age/003/._6716.png
#   inflating: face_age/003/2202.png
#   inflating: __MACOSX/face_age/003/._2202.png
#   inflating: face_age/003/4883.png
#   inflating: __MACOSX/face_age/003/._4883.png
#   inflating: face_age/003/4316.png
#   inflating: __MACOSX/face_age/003/._4316.png
#   inflating: face_age/003/3492.png
#   inflating: __MACOSX/face_age/003/._3492.png
#   inflating: face_age/003/7810.png
#   inflating: __MACOSX/face_age/003/._7810.png
#   inflating: face_age/003/9183.png
#   inflating: __MACOSX/face_age/003/._9183.png
#   inflating: face_age/003/5154.png
#   inflating: __MACOSX/face_age/003/._5154.png
#   inflating: face_age/003/4060.png
#   inflating: __MACOSX/face_age/003/._4060.png
#   inflating: face_age/003/6850.png
#   inflating: __MACOSX/face_age/003/._6850.png
#   inflating: face_age/003/311.png
#   inflating: __MACOSX/face_age/003/._311.png
#   inflating: face_age/003/2415.png
#   inflating: __MACOSX/face_age/003/._2415.png
#   inflating: face_age/003/9756.png
#   inflating: __MACOSX/face_age/003/._9756.png
#   inflating: face_age/003/2987.png
#   inflating: __MACOSX/face_age/003/._2987.png
#   inflating: face_age/003/932.png
#   inflating: __MACOSX/face_age/003/._932.png
#   inflating: face_age/003/4892.png
#   inflating: __MACOSX/face_age/003/._4892.png
#   inflating: face_age/003/7343.png
#   inflating: __MACOSX/face_age/003/._7343.png
#   inflating: face_age/003/7424.png
#   inflating: __MACOSX/face_age/003/._7424.png
#   inflating: face_age/003/2762.png
#   inflating: __MACOSX/face_age/003/._2762.png
#   inflating: face_age/003/9637.png
#   inflating: __MACOSX/face_age/003/._9637.png
#   inflating: face_age/003/1531.png
#   inflating: __MACOSX/face_age/003/._1531.png
#   inflating: face_age/003/6302.png
#   inflating: __MACOSX/face_age/003/._6302.png
#   inflating: face_age/003/4298.png
#   inflating: __MACOSX/face_age/003/._4298.png
#   inflating: face_age/003/338.png
#   inflating: __MACOSX/face_age/003/._338.png
#   inflating: face_age/003/3720.png
#   inflating: __MACOSX/face_age/003/._3720.png
#   inflating: face_age/003/9225.png
#   inflating: __MACOSX/face_age/003/._9225.png
#   inflating: face_age/003/5184.png
#   inflating: __MACOSX/face_age/003/._5184.png
#   inflating: face_age/003/3536.png
#   inflating: __MACOSX/face_age/003/._3536.png
#   inflating: face_age/003/5635.png
#   inflating: __MACOSX/face_age/003/._5635.png
#   inflating: face_age/003/3481.png
#   inflating: __MACOSX/face_age/003/._3481.png
#   inflating: face_age/003/9184.png
#   inflating: __MACOSX/face_age/003/._9184.png
#   inflating: face_age/003/5033.png
#   inflating: __MACOSX/face_age/003/._5033.png
#   inflating: face_age/003/5741.png
#   inflating: __MACOSX/face_age/003/._5741.png
#   inflating: face_age/003/3640.png
#   inflating: __MACOSX/face_age/003/._3640.png
#   inflating: face_age/003/8073.png
#   inflating: __MACOSX/face_age/003/._8073.png
#   inflating: face_age/003/1043.png
#   inflating: __MACOSX/face_age/003/._1043.png
#   inflating: face_age/003/7355.png
#   inflating: __MACOSX/face_age/003/._7355.png
#   inflating: face_age/003/273.png
#   inflating: __MACOSX/face_age/003/._273.png
#   inflating: face_age/003/1095.png
#   inflating: __MACOSX/face_age/003/._1095.png
#   inflating: face_age/003/7037.png
#   inflating: __MACOSX/face_age/003/._7037.png
#   inflating: face_age/003/5191.png
#   inflating: __MACOSX/face_age/003/._5191.png
#   inflating: face_age/003/1485.png
#   inflating: __MACOSX/face_age/003/._1485.png
#   inflating: face_age/003/4714.png
#   inflating: __MACOSX/face_age/003/._4714.png
#   inflating: face_age/003/9556.png
#   inflating: __MACOSX/face_age/003/._9556.png
#   inflating: face_age/003/478.png
#   inflating: __MACOSX/face_age/003/._478.png
#   inflating: face_age/003/1488.png
#   inflating: __MACOSX/face_age/003/._1488.png
#   inflating: face_age/003/3248.png
#   inflating: __MACOSX/face_age/003/._3248.png
#   inflating: face_age/003/6324.png
#   inflating: __MACOSX/face_age/003/._6324.png
#   inflating: face_age/003/9759.png
#   inflating: __MACOSX/face_age/003/._9759.png
#   inflating: face_age/003/2793.png
#   inflating: __MACOSX/face_age/003/._2793.png
#   inflating: face_age/003/7833.png
#   inflating: __MACOSX/face_age/003/._7833.png
#   inflating: face_age/003/2963.png
#   inflating: __MACOSX/face_age/003/._2963.png
#   inflating: face_age/003/2585.png
#   inflating: __MACOSX/face_age/003/._2585.png
#   inflating: face_age/003/4137.png
#   inflating: __MACOSX/face_age/003/._4137.png
#   inflating: face_age/003/5228.png
#   inflating: __MACOSX/face_age/003/._5228.png
#   inflating: face_age/003/8532.png
#   inflating: __MACOSX/face_age/003/._8532.png
#   inflating: face_age/003/5758.png
#   inflating: __MACOSX/face_age/003/._5758.png
#   inflating: face_age/003/7007.png
#   inflating: __MACOSX/face_age/003/._7007.png
#   inflating: face_age/003/9764.png
#   inflating: __MACOSX/face_age/003/._9764.png
#   inflating: face_age/003/8485.png
#   inflating: __MACOSX/face_age/003/._8485.png
#   inflating: face_age/003/6641.png
#   inflating: __MACOSX/face_age/003/._6641.png
#   inflating: face_age/003/4081.png
#   inflating: __MACOSX/face_age/003/._4081.png
#   inflating: face_age/003/8478.png
#   inflating: __MACOSX/face_age/003/._8478.png
#   inflating: face_age/003/7763.png
#   inflating: __MACOSX/face_age/003/._7763.png
#   inflating: face_age/003/8336.png
#   inflating: __MACOSX/face_age/003/._8336.png
#   inflating: face_age/003/2960.png
#   inflating: __MACOSX/face_age/003/._2960.png
#   inflating: face_age/003/6247.png
#   inflating: __MACOSX/face_age/003/._6247.png
#   inflating: face_age/003/2747.png
#   inflating: __MACOSX/face_age/003/._2747.png
#   inflating: face_age/003/4685.png
#   inflating: __MACOSX/face_age/003/._4685.png
#   inflating: face_age/003/2586.png
#   inflating: __MACOSX/face_age/003/._2586.png
#   inflating: face_age/003/6910.png
#   inflating: __MACOSX/face_age/003/._6910.png
#   inflating: face_age/003/527.png
#   inflating: __MACOSX/face_age/003/._527.png
#   inflating: face_age/003/3667.png
#   inflating: __MACOSX/face_age/003/._3667.png
#   inflating: face_age/003/1703.png
#   inflating: __MACOSX/face_age/003/._1703.png
#   inflating: face_age/003/3882.png
#   inflating: __MACOSX/face_age/003/._3882.png
#   inflating: face_age/003/3128.png
#   inflating: __MACOSX/face_age/003/._3128.png
#   inflating: face_age/003/4121.png
#   inflating: __MACOSX/face_age/003/._4121.png
#   inflating: face_age/003/7399.png
#   inflating: __MACOSX/face_age/003/._7399.png
#   inflating: face_age/003/8900.png
#   inflating: __MACOSX/face_age/003/._8900.png
#   inflating: face_age/003/9613.png
#   inflating: __MACOSX/face_age/003/._9613.png
#   inflating: face_age/003/4519.png
#   inflating: __MACOSX/face_age/003/._4519.png
#   inflating: face_age/003/678.png
#   inflating: __MACOSX/face_age/003/._678.png
#   inflating: face_age/003/8121.png
#   inflating: __MACOSX/face_age/003/._8121.png
#   inflating: face_age/003/6859.png
#   inflating: __MACOSX/face_age/003/._6859.png
#   inflating: face_age/003/2408.png
#   inflating: __MACOSX/face_age/003/._2408.png
#   inflating: face_age/003/640.png
#   inflating: __MACOSX/face_age/003/._640.png
#   inflating: face_age/003/3514.png
#   inflating: __MACOSX/face_age/003/._3514.png
#   inflating: face_age/003/2144.png
#   inflating: __MACOSX/face_age/003/._2144.png
#   inflating: face_age/003/2150.png
#   inflating: __MACOSX/face_age/003/._2150.png
#   inflating: face_age/003/7809.png
#   inflating: __MACOSX/face_age/003/._7809.png
#   inflating: face_age/003/5039.png
#   inflating: __MACOSX/face_age/003/._5039.png
#   inflating: face_age/003/3105.png
#   inflating: __MACOSX/face_age/003/._3105.png
#   inflating: face_age/003/7834.png
#   inflating: __MACOSX/face_age/003/._7834.png
#   inflating: face_age/003/1316.png
#   inflating: __MACOSX/face_age/003/._1316.png
#   inflating: face_age/003/2186.png
#   inflating: __MACOSX/face_age/003/._2186.png
#   inflating: face_age/003/133.png
#   inflating: __MACOSX/face_age/003/._133.png
#   inflating: face_age/003/2353.png
#   inflating: __MACOSX/face_age/003/._2353.png
#   inflating: face_age/003/7203.png
#   inflating: __MACOSX/face_age/003/._7203.png
#   inflating: face_age/003/8683.png
#   inflating: __MACOSX/face_age/003/._8683.png
#   inflating: face_age/003/7598.png
#   inflating: __MACOSX/face_age/003/._7598.png
#   inflating: face_age/003/5199.png
#   inflating: __MACOSX/face_age/003/._5199.png
#   inflating: face_age/003/8442.png
#   inflating: __MACOSX/face_age/003/._8442.png
#   inflating: face_age/003/6321.png
#   inflating: __MACOSX/face_age/003/._6321.png
#   inflating: face_age/003/2796.png
#   inflating: __MACOSX/face_age/003/._2796.png
#   inflating: face_age/003/1274.png
#   inflating: __MACOSX/face_age/003/._1274.png
#   inflating: face_age/003/6269.png
#   inflating: __MACOSX/face_age/003/._6269.png
#   inflating: face_age/003/7639.png
#   inflating: __MACOSX/face_age/003/._7639.png
#   inflating: face_age/003/247.png
#   inflating: __MACOSX/face_age/003/._247.png
#   inflating: face_age/003/4132.png
#   inflating: __MACOSX/face_age/003/._4132.png
#   inflating: face_age/003/2230.png
#   inflating: __MACOSX/face_age/003/._2230.png
#   inflating: face_age/003/4133.png
#   inflating: __MACOSX/face_age/003/._4133.png
#   inflating: face_age/003/8709.png
#   inflating: __MACOSX/face_age/003/._8709.png
#   inflating: face_age/003/6718.png
#   inflating: __MACOSX/face_age/003/._6718.png
#   inflating: face_age/003/508.png
#   inflating: __MACOSX/face_age/003/._508.png
#   inflating: face_age/003/4319.png
#   inflating: __MACOSX/face_age/003/._4319.png
#   inflating: face_age/003/4090.png
#   inflating: __MACOSX/face_age/003/._4090.png
#   inflating: face_age/003/6151.png
#   inflating: __MACOSX/face_age/003/._6151.png
#   inflating: face_age/003/7273.png
#   inflating: __MACOSX/face_age/003/._7273.png
#   inflating: face_age/003/4008.png
#   inflating: __MACOSX/face_age/003/._4008.png
#   inflating: face_age/003/6384.png
#   inflating: __MACOSX/face_age/003/._6384.png
#   inflating: face_age/003/631.png
#   inflating: __MACOSX/face_age/003/._631.png
#   inflating: face_age/003/9048.png
#   inflating: __MACOSX/face_age/003/._9048.png
#   inflating: face_age/003/7844.png
#   inflating: __MACOSX/face_age/003/._7844.png
#   inflating: face_age/003/5921.png
#   inflating: __MACOSX/face_age/003/._5921.png
#   inflating: face_age/003/4342.png
#   inflating: __MACOSX/face_age/003/._4342.png
#   inflating: face_age/003/5074.png
#   inflating: __MACOSX/face_age/003/._5074.png
#   inflating: face_age/003/792.png
#   inflating: __MACOSX/face_age/003/._792.png
#   inflating: face_age/003/6970.png
#   inflating: __MACOSX/face_age/003/._6970.png
#   inflating: face_age/003/584.png
#   inflating: __MACOSX/face_age/003/._584.png
#   inflating: face_age/003/1987.png
#   inflating: __MACOSX/face_age/003/._1987.png
#   inflating: face_age/003/234.png
#   inflating: __MACOSX/face_age/003/._234.png
#   inflating: face_age/003/4828.png
#   inflating: __MACOSX/face_age/003/._4828.png
#   inflating: face_age/003/7110.png
#   inflating: __MACOSX/face_age/003/._7110.png
#   inflating: face_age/003/3404.png
#   inflating: __MACOSX/face_age/003/._3404.png
#   inflating: face_age/003/6232.png
#   inflating: __MACOSX/face_age/003/._6232.png
#   inflating: face_age/003/6540.png
#   inflating: __MACOSX/face_age/003/._6540.png
#   inflating: face_age/003/7851.png
#   inflating: __MACOSX/face_age/003/._7851.png
#   inflating: face_age/003/3558.png
#   inflating: __MACOSX/face_age/003/._3558.png
#   inflating: face_age/003/7500.png
#   inflating: __MACOSX/face_age/003/._7500.png
#   inflating: face_age/003/4948.png
#   inflating: __MACOSX/face_age/003/._4948.png
#   inflating: face_age/003/7299.png
#   inflating: __MACOSX/face_age/003/._7299.png
#   inflating: face_age/003/4553.png
#   inflating: __MACOSX/face_age/003/._4553.png
#   inflating: face_age/003/5117.png
#   inflating: __MACOSX/face_age/003/._5117.png
#   inflating: face_age/003/3214.png
#   inflating: __MACOSX/face_age/003/._3214.png
#   inflating: face_age/003/1946.png
#   inflating: __MACOSX/face_age/003/._1946.png
#   inflating: face_age/003/8744.png
#   inflating: __MACOSX/face_age/003/._8744.png
#   inflating: face_age/003/1990.png
#   inflating: __MACOSX/face_age/003/._1990.png
#   inflating: face_age/003/3639.png
#   inflating: __MACOSX/face_age/003/._3639.png
#   inflating: face_age/003/4624.png
#   inflating: __MACOSX/face_age/003/._4624.png
#   inflating: face_age/003/6972.png
#   inflating: __MACOSX/face_age/003/._6972.png
#   inflating: face_age/003/4803.png
#   inflating: __MACOSX/face_age/003/._4803.png
#   inflating: face_age/003/5923.png
#   inflating: __MACOSX/face_age/003/._5923.png
#   inflating: face_age/003/7073.png
#   inflating: __MACOSX/face_age/003/._7073.png
#   inflating: face_age/003/9076.png
#   inflating: __MACOSX/face_age/003/._9076.png
#   inflating: face_age/003/627.png
#   inflating: __MACOSX/face_age/003/._627.png
#   inflating: face_age/003/9506.png
#   inflating: __MACOSX/face_age/003/._9506.png
#   inflating: face_age/003/2321.png
#   inflating: __MACOSX/face_age/003/._2321.png
#   inflating: face_age/003/8195.png
#   inflating: __MACOSX/face_age/003/._8195.png
#   inflating: face_age/003/8191.png
#   inflating: __MACOSX/face_age/003/._8191.png
#   inflating: face_age/003/1374.png
#   inflating: __MACOSX/face_age/003/._1374.png
#   inflating: face_age/003/7739.png
#   inflating: __MACOSX/face_age/003/._7739.png
#   inflating: face_age/003/2709.png
#   inflating: __MACOSX/face_age/003/._2709.png
#   inflating: face_age/003/3615.png
#   inflating: __MACOSX/face_age/003/._3615.png
#   inflating: face_age/003/6779.png
#   inflating: __MACOSX/face_age/003/._6779.png
#   inflating: face_age/003/8768.png
#   inflating: __MACOSX/face_age/003/._8768.png
#   inflating: face_age/003/2522.png
#   inflating: __MACOSX/face_age/003/._2522.png
#   inflating: face_age/003/2536.png
#   inflating: __MACOSX/face_age/003/._2536.png
#   inflating: face_age/003/597.png
#   inflating: __MACOSX/face_age/003/._597.png
#   inflating: face_age/003/971.png
#   inflating: __MACOSX/face_age/003/._971.png
#   inflating: face_age/003/4379.png
#   inflating: __MACOSX/face_age/003/._4379.png
#   inflating: face_age/003/2091.png
#   inflating: __MACOSX/face_age/003/._2091.png
#   inflating: face_age/003/2132.png
#   inflating: __MACOSX/face_age/003/._2132.png
#   inflating: face_age/003/5891.png
#   inflating: __MACOSX/face_age/003/._5891.png
#   inflating: face_age/003/8437.png
#   inflating: __MACOSX/face_age/003/._8437.png
#   inflating: face_age/003/1177.png
#   inflating: __MACOSX/face_age/003/._1177.png
#   inflating: face_age/003/4964.png
#   inflating: __MACOSX/face_age/003/._4964.png
#   inflating: face_age/003/4019.png
#   inflating: __MACOSX/face_age/003/._4019.png
#   inflating: face_age/003/2326.png
#   inflating: __MACOSX/face_age/003/._2326.png
#   inflating: face_age/003/4596.png
#   inflating: __MACOSX/face_age/003/._4596.png
#   inflating: face_age/003/84.png
#   inflating: __MACOSX/face_age/003/._84.png
#   inflating: face_age/003/5111.png
#   inflating: __MACOSX/face_age/003/._5111.png
#   inflating: face_age/003/9688.png
#   inflating: __MACOSX/face_age/003/._9688.png
#   inflating: face_age/003/2087.png
#   inflating: __MACOSX/face_age/003/._2087.png
#   inflating: face_age/003/9313.png
#   inflating: __MACOSX/face_age/003/._9313.png
#   inflating: face_age/003/2253.png
#   inflating: __MACOSX/face_age/003/._2253.png
#   inflating: face_age/003/9312.png
#   inflating: __MACOSX/face_age/003/._9312.png
#   inflating: face_age/003/8965.png
#   inflating: __MACOSX/face_age/003/._8965.png
#   inflating: face_age/003/3830.png
#   inflating: __MACOSX/face_age/003/._3830.png
#   inflating: face_age/003/2045.png
#   inflating: __MACOSX/face_age/003/._2045.png
#   inflating: face_age/003/7673.png
#   inflating: __MACOSX/face_age/003/._7673.png
#   inflating: face_age/003/4597.png
#   inflating: __MACOSX/face_age/003/._4597.png
#   inflating: face_age/003/9528.png
#   inflating: __MACOSX/face_age/003/._9528.png
#   inflating: face_age/003/6182.png
#   inflating: __MACOSX/face_age/003/._6182.png
#   inflating: face_age/003/1809.png
#   inflating: __MACOSX/face_age/003/._1809.png
#   inflating: face_age/004/4773.png
#   inflating: __MACOSX/face_age/004/._4773.png
#   inflating: face_age/004/2464.png
#   inflating: __MACOSX/face_age/004/._2464.png
#   inflating: face_age/004/7911.png
#   inflating: __MACOSX/face_age/004/._7911.png
#   inflating: face_age/004/1390.png
#   inflating: __MACOSX/face_age/004/._1390.png
#   inflating: face_age/004/9121.png
#   inflating: __MACOSX/face_age/004/._9121.png
#   inflating: face_age/004/4439.png
#   inflating: __MACOSX/face_age/004/._4439.png
#   inflating: face_age/004/3183.png
#   inflating: __MACOSX/face_age/004/._3183.png
#   inflating: face_age/004/4175.png
#   inflating: __MACOSX/face_age/004/._4175.png
#   inflating: face_age/004/6010.png
#   inflating: __MACOSX/face_age/004/._6010.png
#   inflating: face_age/004/7441.png
#   inflating: __MACOSX/face_age/004/._7441.png
#   inflating: face_age/004/7119.png
#   inflating: __MACOSX/face_age/004/._7119.png
#   inflating: face_age/004/1420.png
#   inflating: __MACOSX/face_age/004/._1420.png
#   inflating: face_age/004/2667.png
#   inflating: __MACOSX/face_age/004/._2667.png
#   inflating: face_age/004/1144.png
#   inflating: __MACOSX/face_age/004/._1144.png
#   inflating: face_age/004/4772.png
#   inflating: __MACOSX/face_age/004/._4772.png
#   inflating: face_age/004/4014.png
#   inflating: __MACOSX/face_age/004/._4014.png
#   inflating: face_age/004/1191.png
#   inflating: __MACOSX/face_age/004/._1191.png
#   inflating: face_age/004/9095.png
#   inflating: __MACOSX/face_age/004/._9095.png
#   inflating: face_age/004/4374.png
#   inflating: __MACOSX/face_age/004/._4374.png
#   inflating: face_age/004/9136.png
#   inflating: __MACOSX/face_age/004/._9136.png
#   inflating: face_age/004/3427.png
#   inflating: __MACOSX/face_age/004/._3427.png
#   inflating: face_age/004/5527.png
#   inflating: __MACOSX/face_age/004/._5527.png
#   inflating: face_age/004/6947.png
#   inflating: __MACOSX/face_age/004/._6947.png
#   inflating: face_age/004/5282.png
#   inflating: __MACOSX/face_age/004/._5282.png
#   inflating: face_age/004/9484.png
#   inflating: __MACOSX/face_age/004/._9484.png
#   inflating: face_age/004/4349.png
#   inflating: __MACOSX/face_age/004/._4349.png
#   inflating: face_age/004/941.png
#   inflating: __MACOSX/face_age/004/._941.png
#   inflating: face_age/004/5719.png
#   inflating: __MACOSX/face_age/004/._5719.png
#   inflating: face_age/004/7536.png
#   inflating: __MACOSX/face_age/004/._7536.png
#   inflating: face_age/004/5453.png
#   inflating: __MACOSX/face_age/004/._5453.png
#   inflating: face_age/004/6614.png
#   inflating: __MACOSX/face_age/004/._6614.png
#   inflating: face_age/004/4007.png
#   inflating: __MACOSX/face_age/004/._4007.png
#   inflating: face_age/004/7095.png
#   inflating: __MACOSX/face_age/004/._7095.png
#   inflating: face_age/004/2853.png
#   inflating: __MACOSX/face_age/004/._2853.png
#   inflating: face_age/004/9084.png
#   inflating: __MACOSX/face_age/004/._9084.png
#   inflating: face_age/004/3230.png
#   inflating: __MACOSX/face_age/004/._3230.png
#   inflating: face_age/004/7718.png
#   inflating: __MACOSX/face_age/004/._7718.png
#   inflating: face_age/004/4211.png
#   inflating: __MACOSX/face_age/004/._4211.png
#   inflating: face_age/004/5669.png
#   inflating: __MACOSX/face_age/004/._5669.png
#   inflating: face_age/004/6599.png
#   inflating: __MACOSX/face_age/004/._6599.png
#   inflating: face_age/004/7122.png
#   inflating: __MACOSX/face_age/004/._7122.png
#   inflating: face_age/004/6200.png
#   inflating: __MACOSX/face_age/004/._6200.png
#   inflating: face_age/004/9655.png
#   inflating: __MACOSX/face_age/004/._9655.png
#   inflating: face_age/004/1989.png
#   inflating: __MACOSX/face_age/004/._1989.png
#   inflating: face_age/004/3146.png
#   inflating: __MACOSX/face_age/004/._3146.png
#   inflating: face_age/004/4601.png
#   inflating: __MACOSX/face_age/004/._4601.png
#   inflating: face_age/004/2270.png
#   inflating: __MACOSX/face_age/004/._2270.png
#   inflating: face_age/004/3608.png
#   inflating: __MACOSX/face_age/004/._3608.png
#   inflating: face_age/004/2264.png
#   inflating: __MACOSX/face_age/004/._2264.png
#   inflating: face_age/004/5287.png
#   inflating: __MACOSX/face_age/004/._5287.png
#   inflating: face_age/004/9126.png
#   inflating: __MACOSX/face_age/004/._9126.png
#   inflating: face_age/004/1552.png
#   inflating: __MACOSX/face_age/004/._1552.png
#   inflating: face_age/004/4358.png
#   inflating: __MACOSX/face_age/004/._4358.png
#   inflating: face_age/004/9683.png
#   inflating: __MACOSX/face_age/004/._9683.png
#   inflating: face_age/004/2926.png
#   inflating: __MACOSX/face_age/004/._2926.png
#   inflating: face_age/004/5132.png
#   inflating: __MACOSX/face_age/004/._5132.png
#   inflating: face_age/004/7916.png
#   inflating: __MACOSX/face_age/004/._7916.png
#   inflating: face_age/004/6163.png
#   inflating: __MACOSX/face_age/004/._6163.png
#   inflating: face_age/004/4012.png
#   inflating: __MACOSX/face_age/004/._4012.png
#   inflating: face_age/004/3755.png
#   inflating: __MACOSX/face_age/004/._3755.png
#   inflating: face_age/004/4984.png
#   inflating: __MACOSX/face_age/004/._4984.png
#   inflating: face_age/004/1815.png
#   inflating: __MACOSX/face_age/004/._1815.png
#   inflating: face_age/004/8164.png
#   inflating: __MACOSX/face_age/004/._8164.png
#   inflating: face_age/004/8158.png
#   inflating: __MACOSX/face_age/004/._8158.png
#   inflating: face_age/004/6613.png
#   inflating: __MACOSX/face_age/004/._6613.png
#   inflating: face_age/004/5681.png
#   inflating: __MACOSX/face_age/004/._5681.png
#   inflating: face_age/004/1424.png
#   inflating: __MACOSX/face_age/004/._1424.png
#   inflating: face_age/004/8366.png
#   inflating: __MACOSX/face_age/004/._8366.png
#   inflating: face_age/004/6411.png
#   inflating: __MACOSX/face_age/004/._6411.png
#   inflating: face_age/004/4574.png
#   inflating: __MACOSX/face_age/004/._4574.png
#   inflating: face_age/004/3347.png
#   inflating: __MACOSX/face_age/004/._3347.png
#   inflating: face_age/004/3623.png
#   inflating: __MACOSX/face_age/004/._3623.png
#   inflating: face_age/004/3622.png
#   inflating: __MACOSX/face_age/004/._3622.png
#   inflating: face_age/004/4830.png
#   inflating: __MACOSX/face_age/004/._4830.png
#   inflating: face_age/004/3839.png
#   inflating: __MACOSX/face_age/004/._3839.png
#   inflating: face_age/004/4415.png
#   inflating: __MACOSX/face_age/004/._4415.png
#   inflating: face_age/004/1237.png
#   inflating: __MACOSX/face_age/004/._1237.png
#   inflating: face_age/004/7861.png
#   inflating: __MACOSX/face_age/004/._7861.png
#   inflating: face_age/004/2879.png
#   inflating: __MACOSX/face_age/004/._2879.png
#   inflating: face_age/004/4950.png
#   inflating: __MACOSX/face_age/004/._4950.png
#   inflating: face_age/004/7281.png
#   inflating: __MACOSX/face_age/004/._7281.png
#   inflating: face_age/004/370.png
#   inflating: __MACOSX/face_age/004/._370.png
#   inflating: face_age/004/6835.png
#   inflating: __MACOSX/face_age/004/._6835.png
#   inflating: face_age/004/5383.png
#   inflating: __MACOSX/face_age/004/._5383.png
#   inflating: face_age/004/6661.png
#   inflating: __MACOSX/face_age/004/._6661.png
#   inflating: face_age/004/129.png
#   inflating: __MACOSX/face_age/004/._129.png
#   inflating: face_age/004/115.png
#   inflating: __MACOSX/face_age/004/._115.png
#   inflating: face_age/004/3490.png
#   inflating: __MACOSX/face_age/004/._3490.png
#   inflating: face_age/004/2765.png
#   inflating: __MACOSX/face_age/004/._2765.png
#   inflating: face_age/004/1913.png
#   inflating: __MACOSX/face_age/004/._1913.png
#   inflating: face_age/004/1708.png
#   inflating: __MACOSX/face_age/004/._1708.png
#   inflating: face_age/004/2215.png
#   inflating: __MACOSX/face_age/004/._2215.png
#   inflating: face_age/004/1084.png
#   inflating: __MACOSX/face_age/004/._1084.png
#   inflating: face_age/004/7634.png
#   inflating: __MACOSX/face_age/004/._7634.png
#   inflating: face_age/004/2002.png
#   inflating: __MACOSX/face_age/004/._2002.png
#   inflating: face_age/004/672.png
#   inflating: __MACOSX/face_age/004/._672.png
#   inflating: face_age/004/9590.png
#   inflating: __MACOSX/face_age/004/._9590.png
#   inflating: face_age/004/6851.png
#   inflating: __MACOSX/face_age/004/._6851.png
#   inflating: face_age/004/7965.png
#   inflating: __MACOSX/face_age/004/._7965.png
#   inflating: face_age/004/664.png
#   inflating: __MACOSX/face_age/004/._664.png
#   inflating: face_age/004/3281.png
#   inflating: __MACOSX/face_age/004/._3281.png
#   inflating: face_age/004/7018.png
#   inflating: __MACOSX/face_age/004/._7018.png
#   inflating: face_age/004/1455.png
#   inflating: __MACOSX/face_age/004/._1455.png
#   inflating: face_age/004/7193.png
#   inflating: __MACOSX/face_age/004/._7193.png
#   inflating: face_age/004/7636.png
#   inflating: __MACOSX/face_age/004/._7636.png
#   inflating: face_age/004/8934.png
#   inflating: __MACOSX/face_age/004/._8934.png
#   inflating: face_age/004/3109.png
#   inflating: __MACOSX/face_age/004/._3109.png
#   inflating: face_age/004/7637.png
#   inflating: __MACOSX/face_age/004/._7637.png
#   inflating: face_age/004/5975.png
#   inflating: __MACOSX/face_age/004/._5975.png
#   inflating: face_age/004/8289.png
#   inflating: __MACOSX/face_age/004/._8289.png
#   inflating: face_age/004/1332.png
#   inflating: __MACOSX/face_age/004/._1332.png
#   inflating: face_age/004/7780.png
#   inflating: __MACOSX/face_age/004/._7780.png
#   inflating: face_age/004/2411.png
#   inflating: __MACOSX/face_age/004/._2411.png
#   inflating: face_age/004/4921.png
#   inflating: __MACOSX/face_age/004/._4921.png
#   inflating: face_age/004/3737.png
#   inflating: __MACOSX/face_age/004/._3737.png
#   inflating: face_age/004/2818.png
#   inflating: __MACOSX/face_age/004/._2818.png
#   inflating: face_age/004/5965.png
#   inflating: __MACOSX/face_age/004/._5965.png
#   inflating: face_age/004/7814.png
#   inflating: __MACOSX/face_age/004/._7814.png
#   inflating: face_age/004/3327.png
#   inflating: __MACOSX/face_age/004/._3327.png
#   inflating: face_age/004/2776.png
#   inflating: __MACOSX/face_age/004/._2776.png
#   inflating: face_age/004/2979.png
#   inflating: __MACOSX/face_age/004/._2979.png
#   inflating: face_age/004/7791.png
#   inflating: __MACOSX/face_age/004/._7791.png
#   inflating: face_age/004/8688.png
#   inflating: __MACOSX/face_age/004/._8688.png
#   inflating: face_age/004/3939.png
#   inflating: __MACOSX/face_age/004/._3939.png
#   inflating: face_age/004/6880.png
#   inflating: __MACOSX/face_age/004/._6880.png
#   inflating: face_age/004/4477.png
#   inflating: __MACOSX/face_age/004/._4477.png
#   inflating: face_age/004/2562.png
#   inflating: __MACOSX/face_age/004/._2562.png
#   inflating: face_age/004/2576.png
#   inflating: __MACOSX/face_age/004/._2576.png
#   inflating: face_age/004/3669.png
#   inflating: __MACOSX/face_age/004/._3669.png
#   inflating: face_age/004/4884.png
#   inflating: __MACOSX/face_age/004/._4884.png
#   inflating: face_age/004/9608.png
#   inflating: __MACOSX/face_age/004/._9608.png
#   inflating: face_age/004/688.png
#   inflating: __MACOSX/face_age/004/._688.png
#   inflating: face_age/004/7023.png
#   inflating: __MACOSX/face_age/004/._7023.png
#   inflating: face_age/004/7976.png
#   inflating: __MACOSX/face_age/004/._7976.png
#   inflating: face_age/004/2371.png
#   inflating: __MACOSX/face_age/004/._2371.png
#   inflating: face_age/004/1678.png
#   inflating: __MACOSX/face_age/004/._1678.png
#   inflating: face_age/004/4728.png
#   inflating: __MACOSX/face_age/004/._4728.png
#   inflating: face_age/004/6659.png
#   inflating: __MACOSX/face_age/004/._6659.png
#   inflating: face_age/004/8106.png
#   inflating: __MACOSX/face_age/004/._8106.png
#   inflating: face_age/004/5387.png
#   inflating: __MACOSX/face_age/004/._5387.png
#   inflating: face_age/004/2156.png
#   inflating: __MACOSX/face_age/004/._2156.png
#   inflating: face_age/004/21.png
#   inflating: __MACOSX/face_age/004/._21.png
#   inflating: face_age/004/4255.png
#   inflating: __MACOSX/face_age/004/._4255.png
#   inflating: face_age/004/7199.png
#   inflating: __MACOSX/face_age/004/._7199.png
#   inflating: face_age/004/3857.png
#   inflating: __MACOSX/face_age/004/._3857.png
#   inflating: face_age/004/4686.png
#   inflating: __MACOSX/face_age/004/._4686.png
#   inflating: face_age/004/280.png
#   inflating: __MACOSX/face_age/004/._280.png
#   inflating: face_age/004/6721.png
#   inflating: __MACOSX/face_age/004/._6721.png
#   inflating: face_age/004/531.png
#   inflating: __MACOSX/face_age/004/._531.png
#   inflating: face_age/004/900.png
#   inflating: __MACOSX/face_age/004/._900.png
#   inflating: face_age/004/7826.png
#   inflating: __MACOSX/face_age/004/._7826.png
#   inflating: face_age/004/5162.png
#   inflating: __MACOSX/face_age/004/._5162.png
#   inflating: face_age/004/690.png
#   inflating: __MACOSX/face_age/004/._690.png
#   inflating: face_age/004/4254.png
#   inflating: __MACOSX/face_age/004/._4254.png
#   inflating: face_age/004/6494.png
#   inflating: __MACOSX/face_age/004/._6494.png
#   inflating: face_age/004/1112.png
#   inflating: __MACOSX/face_age/004/._1112.png
#   inflating: face_age/004/4929.png
#   inflating: __MACOSX/face_age/004/._4929.png
#   inflating: face_age/004/3049.png
#   inflating: __MACOSX/face_age/004/._3049.png
#   inflating: face_age/004/1676.png
#   inflating: __MACOSX/face_age/004/._1676.png
#   inflating: face_age/004/137.png
#   inflating: __MACOSX/face_age/004/._137.png
#   inflating: face_age/004/3465.png
#   inflating: __MACOSX/face_age/004/._3465.png
#   inflating: face_age/004/3897.png
#   inflating: __MACOSX/face_age/004/._3897.png
#   inflating: face_age/004/6737.png
#   inflating: __MACOSX/face_age/004/._6737.png
#   inflating: face_age/004/3883.png
#   inflating: __MACOSX/face_age/004/._3883.png
#   inflating: face_age/004/3114.png
#   inflating: __MACOSX/face_age/004/._3114.png
#   inflating: face_age/004/2752.png
#   inflating: __MACOSX/face_age/004/._2752.png
#   inflating: face_age/004/6291.png
#   inflating: __MACOSX/face_age/004/._6291.png
#   inflating: face_age/004/888.png
#   inflating: __MACOSX/face_age/004/._888.png
#   inflating: face_age/004/9559.png
#   inflating: __MACOSX/face_age/004/._9559.png
#   inflating: face_age/004/6130.png
#   inflating: __MACOSX/face_age/004/._6130.png
#   inflating: face_age/004/4727.png
#   inflating: __MACOSX/face_age/004/._4727.png
#   inflating: face_age/004/8870.png
#   inflating: __MACOSX/face_age/004/._8870.png
#   inflating: face_age/004/5415.png
#   inflating: __MACOSX/face_age/004/._5415.png
#   inflating: face_age/004/126.png
#   inflating: __MACOSX/face_age/004/._126.png
#   inflating: face_age/004/9005.png
#   inflating: __MACOSX/face_age/004/._9005.png
#   inflating: face_age/004/4441.png
#   inflating: __MACOSX/face_age/004/._4441.png
#   inflating: face_age/004/3110.png
#   inflating: __MACOSX/face_age/004/._3110.png
#   inflating: face_age/004/6727.png
#   inflating: __MACOSX/face_age/004/._6727.png
#   inflating: face_age/004/9164.png
#   inflating: __MACOSX/face_age/004/._9164.png
#   inflating: face_age/004/2435.png
#   inflating: __MACOSX/face_age/004/._2435.png
#   inflating: face_age/004/3059.png
#   inflating: __MACOSX/face_age/004/._3059.png
#   inflating: face_age/004/8130.png
#   inflating: __MACOSX/face_age/004/._8130.png
#   inflating: face_age/004/331.png
#   inflating: __MACOSX/face_age/004/._331.png
#   inflating: face_age/004/6874.png
#   inflating: __MACOSX/face_age/004/._6874.png
#   inflating: face_age/004/1869.png
#   inflating: __MACOSX/face_age/004/._1869.png
#   inflating: face_age/004/7573.png
#   inflating: __MACOSX/face_age/004/._7573.png
#   inflating: face_age/004/8640.png
#   inflating: __MACOSX/face_age/004/._8640.png
#   inflating: face_age/004/5748.png
#   inflating: __MACOSX/face_age/004/._5748.png
#   inflating: face_age/004/8913.png
#   inflating: __MACOSX/face_age/004/._8913.png
#   inflating: face_age/004/2219.png
#   inflating: __MACOSX/face_age/004/._2219.png
#   inflating: face_age/004/7413.png
#   inflating: __MACOSX/face_age/004/._7413.png
#   inflating: face_age/004/1063.png
#   inflating: __MACOSX/face_age/004/._1063.png
#   inflating: face_age/004/8906.png
#   inflating: __MACOSX/face_age/004/._8906.png
#   inflating: face_age/004/1507.png
#   inflating: __MACOSX/face_age/004/._1507.png
#   inflating: face_age/004/2973.png
#   inflating: __MACOSX/face_age/004/._2973.png
#   inflating: face_age/004/9775.png
#   inflating: __MACOSX/face_age/004/._9775.png
#   inflating: face_age/004/7016.png
#   inflating: __MACOSX/face_age/004/._7016.png
#   inflating: face_age/004/3728.png
#   inflating: __MACOSX/face_age/004/._3728.png
#   inflating: face_age/004/3714.png
#   inflating: __MACOSX/face_age/004/._3714.png
#   inflating: face_age/004/8127.png
#   inflating: __MACOSX/face_age/004/._8127.png
#   inflating: face_age/004/3927.png
#   inflating: __MACOSX/face_age/004/._3927.png
#   inflating: face_age/004/6877.png
#   inflating: __MACOSX/face_age/004/._6877.png
#   inflating: face_age/004/1831.png
#   inflating: __MACOSX/face_age/004/._1831.png
#   inflating: face_age/004/8829.png
#   inflating: __MACOSX/face_age/004/._8829.png
#   inflating: face_age/004/9262.png
#   inflating: __MACOSX/face_age/004/._9262.png
#   inflating: face_age/004/7930.png
#   inflating: __MACOSX/face_age/004/._7930.png
#   inflating: face_age/004/2874.png
#   inflating: __MACOSX/face_age/004/._2874.png
#   inflating: face_age/004/8395.png
#   inflating: __MACOSX/face_age/004/._8395.png
#   inflating: face_age/004/3405.png
#   inflating: __MACOSX/face_age/004/._3405.png
#   inflating: face_age/004/3377.png
#   inflating: __MACOSX/face_age/004/._3377.png
#   inflating: face_age/004/3808.png
#   inflating: __MACOSX/face_age/004/._3808.png
#   inflating: face_age/004/6025.png
#   inflating: __MACOSX/face_age/004/._6025.png
#   inflating: face_age/004/2257.png
#   inflating: __MACOSX/face_age/004/._2257.png
#   inflating: face_age/004/7306.png
#   inflating: __MACOSX/face_age/004/._7306.png
#   inflating: face_age/004/5539.png
#   inflating: __MACOSX/face_age/004/._5539.png
#   inflating: face_age/004/5288.png
#   inflating: __MACOSX/face_age/004/._5288.png
#   inflating: face_age/004/3821.png
#   inflating: __MACOSX/face_age/004/._3821.png
#   inflating: face_age/004/6568.png
#   inflating: __MACOSX/face_age/004/._6568.png
#   inflating: face_age/004/140.png
#   inflating: __MACOSX/face_age/004/._140.png
#   inflating: face_age/004/69.png
#   inflating: __MACOSX/face_age/004/._69.png
#   inflating: face_age/004/1403.png
#   inflating: __MACOSX/face_age/004/._1403.png
#   inflating: face_age/004/2917.png
#   inflating: __MACOSX/face_age/004/._2917.png
#   inflating: face_age/004/4143.png
#   inflating: __MACOSX/face_age/004/._4143.png
#   inflating: face_age/004/7891.png
#   inflating: __MACOSX/face_age/004/._7891.png
#   inflating: face_age/004/7503.png
#   inflating: __MACOSX/face_age/004/._7503.png
#   inflating: face_age/004/9512.png
#   inflating: __MACOSX/face_age/004/._9512.png
#   inflating: face_age/004/4988.png
#   inflating: __MACOSX/face_age/004/._4988.png
#   inflating: face_age/004/3942.png
#   inflating: __MACOSX/face_age/004/._3942.png
#   inflating: face_age/004/8152.png
#   inflating: __MACOSX/face_age/004/._8152.png
#   inflating: face_age/004/3007.png
#   inflating: __MACOSX/face_age/004/._3007.png
#   inflating: face_age/004/4754.png
#   inflating: __MACOSX/face_age/004/._4754.png
#   inflating: face_age/004/8436.png
#   inflating: __MACOSX/face_age/004/._8436.png
#   inflating: face_age/004/3205.png
#   inflating: __MACOSX/face_age/004/._3205.png
#   inflating: face_age/004/6341.png
#   inflating: __MACOSX/face_age/004/._6341.png
#   inflating: face_age/004/9072.png
#   inflating: __MACOSX/face_age/004/._9072.png
#   inflating: face_age/004/4542.png
#   inflating: __MACOSX/face_age/004/._4542.png
#   inflating: face_age/004/8224.png
#   inflating: __MACOSX/face_age/004/._8224.png
#   inflating: face_age/004/970.png
#   inflating: __MACOSX/face_age/004/._970.png
#   inflating: face_age/004/4153.png
#   inflating: __MACOSX/face_age/004/._4153.png
#   inflating: face_age/004/7300.png
#   inflating: __MACOSX/face_age/004/._7300.png
#   inflating: face_age/004/1956.png
#   inflating: __MACOSX/face_age/004/._1956.png
#   inflating: face_age/004/6432.png
#   inflating: __MACOSX/face_age/004/._6432.png
#   inflating: face_age/004/79.png
#   inflating: __MACOSX/face_age/004/._79.png
#   inflating: face_age/004/436.png
#   inflating: __MACOSX/face_age/004/._436.png
#   inflating: face_age/004/2497.png
#   inflating: __MACOSX/face_age/004/._2497.png
#   inflating: face_age/004/3789.png
#   inflating: __MACOSX/face_age/004/._3789.png
#   inflating: face_age/004/9065.png
#   inflating: __MACOSX/face_age/004/._9065.png
#   inflating: face_age/004/8596.png
#   inflating: __MACOSX/face_age/004/._8596.png
#   inflating: face_age/004/5703.png
#   inflating: __MACOSX/face_age/004/._5703.png
#   inflating: face_age/004/967.png
#   inflating: __MACOSX/face_age/004/._967.png
#   inflating: face_age/004/8794.png
#   inflating: __MACOSX/face_age/004/._8794.png
#   inflating: face_age/004/8756.png
#   inflating: __MACOSX/face_age/004/._8756.png
#   inflating: face_age/004/1799.png
#   inflating: __MACOSX/face_age/004/._1799.png
#   inflating: face_age/004/1558.png
#   inflating: __MACOSX/face_age/004/._1558.png
#   inflating: face_age/004/782.png
#   inflating: __MACOSX/face_age/004/._782.png
#   inflating: face_age/004/4385.png
#   inflating: __MACOSX/face_age/004/._4385.png
#   inflating: face_age/004/2643.png
#   inflating: __MACOSX/face_age/004/._2643.png
#   inflating: face_age/004/3549.png
#   inflating: __MACOSX/face_age/004/._3549.png
#   inflating: face_age/004/6627.png
#   inflating: __MACOSX/face_age/004/._6627.png
#   inflating: face_age/004/3777.png
#   inflating: __MACOSX/face_age/004/._3777.png
#   inflating: face_age/032/5486.png
#   inflating: __MACOSX/face_age/032/._5486.png
#   inflating: face_age/032/2869.png
#   inflating: __MACOSX/face_age/032/._2869.png
#   inflating: face_age/032/638.png
#   inflating: __MACOSX/face_age/032/._638.png
#   inflating: face_age/032/176.png
#   inflating: __MACOSX/face_age/032/._176.png
#   inflating: face_age/032/6979.png
#   inflating: __MACOSX/face_age/032/._6979.png
#   inflating: face_age/032/2713.png
#   inflating: __MACOSX/face_age/032/._2713.png
#   inflating: face_age/032/8410.png
#   inflating: __MACOSX/face_age/032/._8410.png
#   inflating: face_age/032/5652.png
#   inflating: __MACOSX/face_age/032/._5652.png
#   inflating: face_age/032/7535.png
#   inflating: __MACOSX/face_age/032/._7535.png
#   inflating: face_age/032/407.png
#   inflating: __MACOSX/face_age/032/._407.png
#   inflating: face_age/032/9532.png
#   inflating: __MACOSX/face_age/032/._9532.png
#   inflating: face_age/032/4214.png
#   inflating: __MACOSX/face_age/032/._4214.png
#   inflating: face_age/032/3547.png
#   inflating: __MACOSX/face_age/032/._3547.png
#   inflating: face_age/032/6211.png
#   inflating: __MACOSX/face_age/032/._6211.png
#   inflating: face_age/032/7697.png
#   inflating: __MACOSX/face_age/032/._7697.png
#   inflating: face_age/032/1635.png
#   inflating: __MACOSX/face_age/032/._1635.png
#   inflating: face_age/032/4371.png
#   inflating: __MACOSX/face_age/032/._4371.png
#   inflating: face_age/032/2700.png
#   inflating: __MACOSX/face_age/032/._2700.png
#   inflating: face_age/032/3152.png
#   inflating: __MACOSX/face_age/032/._3152.png
#   inflating: face_age/032/6770.png
#   inflating: __MACOSX/face_age/032/._6770.png
#   inflating: face_age/032/5536.png
#   inflating: __MACOSX/face_age/032/._5536.png
#   inflating: face_age/032/3190.png
#   inflating: __MACOSX/face_age/032/._3190.png
#   inflating: face_age/032/3231.png
#   inflating: __MACOSX/face_age/032/._3231.png
#   inflating: face_age/032/4979.png
#   inflating: __MACOSX/face_age/032/._4979.png
#   inflating: face_age/032/7525.png
#   inflating: __MACOSX/face_age/032/._7525.png
#   inflating: face_age/032/3838.png
#   inflating: __MACOSX/face_age/032/._3838.png
#   inflating: face_age/032/8776.png
#   inflating: __MACOSX/face_age/032/._8776.png
#   inflating: face_age/032/3178.png
#   inflating: __MACOSX/face_age/032/._3178.png
#   inflating: face_age/032/9535.png
#   inflating: __MACOSX/face_age/032/._9535.png
#   inflating: face_age/032/6606.png
#   inflating: __MACOSX/face_age/032/._6606.png
#   inflating: face_age/032/2375.png
#   inflating: __MACOSX/face_age/032/._2375.png
#   inflating: face_age/032/6649.png
#   inflating: __MACOSX/face_age/032/._6649.png
# ...
#   inflating: face_age/058/878.png
#   inflating: __MACOSX/face_age/058/._878.png
#   inflating: face_age/058/9595.png
#   inflating: __MACOSX/face_age/058/._9595.png
#   inflating: face_age/058/7953.png
#   inflating: __MACOSX/face_age/058/._7953.png
#   inflating: face_age/058/5836.png
#   inflating: __MACOSX/face_age/058/._5836.png
#   inflating: face_age/058/1477.png
#   inflating: __MACOSX/face_age/058/._1477.png
#   inflating: face_age/058/7417.png
#   inflating: __MACOSX/face_age/058/._7417.png
#   inflating: face_age/058/2355.png
#   inflating: __MACOSX/face_age/058/._2355.png
#   inflating: face_age/058/1886.png
#   inflating: __MACOSX/face_age/058/._1886.png
#   inflating: face_age/058/1104.png
#   inflating: __MACOSX/face_age/058/._1104.png
#   inflating: face_age/058/9766.png
#   inflating: __MACOSX/face_age/058/._9766.png
#   inflating: face_age/058/4849.png
#   inflating: __MACOSX/face_age/058/._4849.png
#   inflating: face_age/058/37.png
#   inflating: __MACOSX/face_age/058/._37.png
#   inflating: face_age/058/3138.png
#   inflating: __MACOSX/face_age/058/._3138.png
#   inflating: face_age/058/286.png
#   inflating: __MACOSX/face_age/058/._286.png
#   inflating: face_age/058/8087.png
#   inflating: __MACOSX/face_age/058/._8087.png
#   inflating: face_age/058/906.png
#   inflating: __MACOSX/face_age/058/._906.png
#   inflating: face_age/058/5831.png
#   inflating: __MACOSX/face_age/058/._5831.png
#   inflating: face_age/058/8642.png
#   inflating: __MACOSX/face_age/058/._8642.png
#   inflating: face_age/058/737.png
#   inflating: __MACOSX/face_age/058/._737.png
#   inflating: face_age/058/8250.png
#   inflating: __MACOSX/face_age/058/._8250.png
#   inflating: face_age/058/3846.png
#   inflating: __MACOSX/face_age/058/._3846.png
#   inflating: face_age/058/1088.png
#   inflating: __MACOSX/face_age/058/._1088.png
#   inflating: face_age/058/865.png
#   inflating: __MACOSX/face_age/058/._865.png
#   inflating: face_age/058/6452.png
#   inflating: __MACOSX/face_age/058/._6452.png
#   inflating: face_age/058/695.png
#   inflating: __MACOSX/face_age/058/._695.png
#   inflating: face_age/058/1895.png
#   inflating: __MACOSX/face_age/058/._1895.png
#   inflating: face_age/058/9239.png
#   inflating: __MACOSX/face_age/058/._9239.png
#   inflating: face_age/058/2337.png
#   inflating: __MACOSX/face_age/058/._2337.png
#   inflating: face_age/058/5276.png
#   inflating: __MACOSX/face_age/058/._5276.png
#   inflating: face_age/058/6144.png
#   inflating: __MACOSX/face_age/058/._6144.png
#   inflating: face_age/058/8396.png
#   inflating: __MACOSX/face_age/058/._8396.png
#   inflating: face_age/058/9117.png
#   inflating: __MACOSX/face_age/058/._9117.png
#   inflating: face_age/058/222.png
#   inflating: __MACOSX/face_age/058/._222.png
#   inflating: face_age/058/4354.png
#   inflating: __MACOSX/face_age/058/._4354.png
#   inflating: face_age/058/2094.png
#   inflating: __MACOSX/face_age/058/._2094.png
#   inflating: face_age/058/6386.png
#   inflating: __MACOSX/face_age/058/._6386.png
#   inflating: face_age/058/4797.png
#   inflating: __MACOSX/face_age/058/._4797.png
#   inflating: face_age/058/7936.png
#   inflating: __MACOSX/face_age/058/._7936.png
#   inflating: face_age/058/5259.png
#   inflating: __MACOSX/face_age/058/._5259.png
#   inflating: face_age/058/3166.png
#   inflating: __MACOSX/face_age/058/._3166.png
#   inflating: face_age/058/5463.png
#   inflating: __MACOSX/face_age/058/._5463.png
#   inflating: face_age/058/7506.png
#   inflating: __MACOSX/face_age/058/._7506.png
#   inflating: face_age/058/350.png
#   inflating: __MACOSX/face_age/058/._350.png
#   inflating: face_age/058/7712.png
#   inflating: __MACOSX/face_age/058/._7712.png
#   inflating: face_age/058/4805.png
#   inflating: __MACOSX/face_age/058/._4805.png
#   inflating: face_age/058/3401.png
#   inflating: __MACOSX/face_age/058/._3401.png
#   inflating: face_age/058/2657.png
#   inflating: __MACOSX/face_age/058/._2657.png
#   inflating: face_age/058/9500.png
#   inflating: __MACOSX/face_age/058/._9500.png
#   inflating: face_age/058/6800.png
#   inflating: __MACOSX/face_age/058/._6800.png
#   inflating: face_age/060/770.png
#   inflating: __MACOSX/face_age/060/._770.png
#   inflating: face_age/060/6789.png
#   inflating: __MACOSX/face_age/060/._6789.png
#   inflating: face_age/060/8983.png
#   inflating: __MACOSX/face_age/060/._8983.png
#   inflating: face_age/060/3154.png
#   inflating: __MACOSX/face_age/060/._3154.png
#   inflating: face_age/060/8160.png
#   inflating: __MACOSX/face_age/060/._8160.png
#   inflating: face_age/060/4955.png
#   inflating: __MACOSX/face_age/060/._4955.png
#   inflating: face_age/060/7279.png
#   inflating: __MACOSX/face_age/060/._7279.png
#   inflating: face_age/060/9042.png
#   inflating: __MACOSX/face_age/060/._9042.png
#   inflating: face_age/060/773.png
#   inflating: __MACOSX/face_age/060/._773.png
#   inflating: face_age/060/7133.png
#   inflating: __MACOSX/face_age/060/._7133.png
#   inflating: face_age/060/4823.png
#   inflating: __MACOSX/face_age/060/._4823.png
#   inflating: face_age/060/7331.png
#   inflating: __MACOSX/face_age/060/._7331.png
#   inflating: face_age/060/2512.png
#   inflating: __MACOSX/face_age/060/._2512.png
#   inflating: face_age/060/1580.png
#   inflating: __MACOSX/face_age/060/._1580.png
#   inflating: face_age/060/8836.png
#   inflating: __MACOSX/face_age/060/._8836.png
#   inflating: face_age/060/5696.png
#   inflating: __MACOSX/face_age/060/._5696.png
#   inflating: face_age/060/7903.png
#   inflating: __MACOSX/face_age/060/._7903.png
#   inflating: face_age/060/5866.png
#   inflating: __MACOSX/face_age/060/._5866.png
#   inflating: face_age/060/825.png
#   inflating: __MACOSX/face_age/060/._825.png
#   inflating: face_age/060/4359.png
#   inflating: __MACOSX/face_age/060/._4359.png
#   inflating: face_age/060/4826.png
#   inflating: __MACOSX/face_age/060/._4826.png
#   inflating: face_age/060/6016.png
#   inflating: __MACOSX/face_age/060/._6016.png
#   inflating: face_age/060/8416.png
#   inflating: __MACOSX/face_age/060/._8416.png
#   inflating: face_age/060/1142.png
#   inflating: __MACOSX/face_age/060/._1142.png
#   inflating: face_age/060/3796.png
#   inflating: __MACOSX/face_age/060/._3796.png
#   inflating: face_age/060/3958.png
#   inflating: __MACOSX/face_age/060/._3958.png
#   inflating: face_age/060/3025.png
#   inflating: __MACOSX/face_age/060/._3025.png
#   inflating: face_age/060/3227.png
#   inflating: __MACOSX/face_age/060/._3227.png
#   inflating: face_age/060/6559.png
#   inflating: __MACOSX/face_age/060/._6559.png
#   inflating: face_age/060/4372.png
#   inflating: __MACOSX/face_age/060/._4372.png
#   inflating: face_age/060/9326.png
#   inflating: __MACOSX/face_age/060/._9326.png
#   inflating: face_age/060/2273.png
#   inflating: __MACOSX/face_age/060/._2273.png
#   inflating: face_age/060/6772.png
#   inflating: __MACOSX/face_age/060/._6772.png
#   inflating: face_age/060/4165.png
#   inflating: __MACOSX/face_age/060/._4165.png
#   inflating: face_age/060/5858.png
#   inflating: __MACOSX/face_age/060/._5858.png
#   inflating: face_age/060/1654.png
#   inflating: __MACOSX/face_age/060/._1654.png
#   inflating: face_age/060/6265.png
#   inflating: __MACOSX/face_age/060/._6265.png
#   inflating: face_age/060/7423.png
#   inflating: __MACOSX/face_age/060/._7423.png
#   inflating: face_age/060/3888.png
#   inflating: __MACOSX/face_age/060/._3888.png
#   inflating: face_age/060/5590.png
#   inflating: __MACOSX/face_age/060/._5590.png
#   inflating: face_age/060/7620.png
#   inflating: __MACOSX/face_age/060/._7620.png
#   inflating: face_age/060/5779.png
#   inflating: __MACOSX/face_age/060/._5779.png
#   inflating: face_age/060/3083.png
#   inflating: __MACOSX/face_age/060/._3083.png
#   inflating: face_age/060/9223.png
#   inflating: __MACOSX/face_age/060/._9223.png
#   inflating: face_age/060/5357.png
#   inflating: __MACOSX/face_age/060/._5357.png
#   inflating: face_age/060/4539.png
#   inflating: __MACOSX/face_age/060/._4539.png
#   inflating: face_age/060/3450.png
#   inflating: __MACOSX/face_age/060/._3450.png
#   inflating: face_age/060/5579.png
#   inflating: __MACOSX/face_age/060/._5579.png
#   inflating: face_age/060/7420.png
#   inflating: __MACOSX/face_age/060/._7420.png
#   inflating: face_age/060/3445.png
#   inflating: __MACOSX/face_age/060/._3445.png
#   inflating: face_age/060/1497.png
#   inflating: __MACOSX/face_age/060/._1497.png
#   inflating: face_age/060/8676.png
#   inflating: __MACOSX/face_age/060/._8676.png
#   inflating: face_age/060/6511.png
#   inflating: __MACOSX/face_age/060/._6511.png
#   inflating: face_age/060/4850.png
#   inflating: __MACOSX/face_age/060/._4850.png
#   inflating: face_age/060/3859.png
#   inflating: __MACOSX/face_age/060/._3859.png
#   inflating: face_age/060/5019.png
#   inflating: __MACOSX/face_age/060/._5019.png
#   inflating: face_age/060/853.png
#   inflating: __MACOSX/face_age/060/._853.png
#   inflating: face_age/060/7975.png
#   inflating: __MACOSX/face_age/060/._7975.png
#   inflating: face_age/060/7220.png
#   inflating: __MACOSX/face_age/060/._7220.png
#   inflating: face_age/060/4067.png
#   inflating: __MACOSX/face_age/060/._4067.png
#   inflating: face_age/060/1533.png
#   inflating: __MACOSX/face_age/060/._1533.png
#   inflating: face_age/060/2012.png
#   inflating: __MACOSX/face_age/060/._2012.png
#   inflating: face_age/060/8701.png
#   inflating: __MACOSX/face_age/060/._8701.png
#   inflating: face_age/060/2210.png
#   inflating: __MACOSX/face_age/060/._2210.png
#   inflating: face_age/060/7396.png
#   inflating: __MACOSX/face_age/060/._7396.png
#   inflating: face_age/060/9191.png
#   inflating: __MACOSX/face_age/060/._9191.png
#   inflating: face_age/060/4489.png
#   inflating: __MACOSX/face_age/060/._4489.png
#   inflating: face_age/060/2195.png
#   inflating: __MACOSX/face_age/060/._2195.png
#   inflating: face_age/060/134.png
#   inflating: __MACOSX/face_age/060/._134.png
#   inflating: face_age/060/3274.png
#   inflating: __MACOSX/face_age/060/._3274.png
#   inflating: face_age/060/6250.png
#   inflating: __MACOSX/face_age/060/._6250.png
#   inflating: face_age/060/7172.png
#   inflating: __MACOSX/face_age/060/._7172.png
#   inflating: face_age/060/9639.png
#   inflating: __MACOSX/face_age/060/._9639.png
#   inflating: face_age/060/1932.png
#   inflating: __MACOSX/face_age/060/._1932.png
#   inflating: face_age/060/525.png
#   inflating: __MACOSX/face_age/060/._525.png
#   inflating: face_age/060/7173.png
#   inflating: __MACOSX/face_age/060/._7173.png
#   inflating: face_age/060/8334.png
#   inflating: __MACOSX/face_age/060/._8334.png
#   inflating: face_age/060/121.png
#   inflating: __MACOSX/face_age/060/._121.png
#   inflating: face_age/060/2816.png
#   inflating: __MACOSX/face_age/060/._2816.png
#   inflating: face_age/060/3277.png
#   inflating: __MACOSX/face_age/060/._3277.png
#   inflating: face_age/060/9174.png
#   inflating: __MACOSX/face_age/060/._9174.png
#   inflating: face_age/060/4646.png
#   inflating: __MACOSX/face_age/060/._4646.png
#   inflating: face_age/060/9175.png
#   inflating: __MACOSX/face_age/060/._9175.png
#   inflating: face_age/060/2168.png
#   inflating: __MACOSX/face_age/060/._2168.png
#   inflating: face_age/060/4525.png
#   inflating: __MACOSX/face_age/060/._4525.png
#   inflating: face_age/060/1878.png
#   inflating: __MACOSX/face_age/060/._1878.png
#   inflating: face_age/060/4910.png
#   inflating: __MACOSX/face_age/060/._4910.png
#   inflating: face_age/060/867.png
#   inflating: __MACOSX/face_age/060/._867.png
#   inflating: face_age/060/5788.png
#   inflating: __MACOSX/face_age/060/._5788.png
#   inflating: face_age/060/3474.png
#   inflating: __MACOSX/face_age/060/._3474.png
#   inflating: face_age/060/8910.png
#   inflating: __MACOSX/face_age/060/._8910.png
#   inflating: face_age/060/4119.png
#   inflating: __MACOSX/face_age/060/._4119.png
#   inflating: face_age/060/8737.png
#   inflating: __MACOSX/face_age/060/._8737.png
#   inflating: face_age/060/9401.png
#   inflating: __MACOSX/face_age/060/._9401.png
#   inflating: face_age/060/3139.png
#   inflating: __MACOSX/face_age/060/._3139.png
#   inflating: face_age/060/5004.png
#   inflating: __MACOSX/face_age/060/._5004.png
#   inflating: face_age/060/8326.png
#   inflating: __MACOSX/face_age/060/._8326.png
#   inflating: face_age/060/8279.png
#   inflating: __MACOSX/face_age/060/._8279.png
#   inflating: face_age/060/3954.png
#   inflating: __MACOSX/face_age/060/._3954.png
#   inflating: face_age/060/4785.png
#   inflating: __MACOSX/face_age/060/._4785.png
#   inflating: face_age/060/4034.png
#   inflating: __MACOSX/face_age/060/._4034.png
#   inflating: face_age/060/2525.png
#   inflating: __MACOSX/face_age/060/._2525.png
#   inflating: face_age/060/1038.png
#   inflating: __MACOSX/face_age/060/._1038.png
#   inflating: face_age/060/585.png
#   inflating: __MACOSX/face_age/060/._585.png
#   inflating: face_age/060/3148.png
#   inflating: __MACOSX/face_age/060/._3148.png
#   inflating: face_age/060/9317.png
#   inflating: __MACOSX/face_age/060/._9317.png
#   inflating: face_age/060/4357.png
#   inflating: __MACOSX/face_age/060/._4357.png
#   inflating: face_age/060/4380.png
#   inflating: __MACOSX/face_age/060/._4380.png
#   inflating: face_age/060/6352.png
#   inflating: __MACOSX/face_age/060/._6352.png
#   inflating: face_age/060/2478.png
#   inflating: __MACOSX/face_age/060/._2478.png
#   inflating: face_age/060/2322.png
#   inflating: __MACOSX/face_age/060/._2322.png
#   inflating: face_age/060/2450.png
#   inflating: __MACOSX/face_age/060/._2450.png
#   inflating: face_age/060/4974.png
#   inflating: __MACOSX/face_age/060/._4974.png
#   inflating: face_age/060/418.png
#   inflating: __MACOSX/face_age/060/._418.png
#   inflating: face_age/060/2334.png
#   inflating: __MACOSX/face_age/060/._2334.png
#   inflating: face_age/060/6608.png
#   inflating: __MACOSX/face_age/060/._6608.png
#   inflating: face_age/060/4396.png
#   inflating: __MACOSX/face_age/060/._4396.png
#   inflating: face_age/060/2081.png
#   inflating: __MACOSX/face_age/060/._2081.png
#   inflating: face_age/060/4194.png
#   inflating: __MACOSX/face_age/060/._4194.png
#   inflating: face_age/060/1006.png
#   inflating: __MACOSX/face_age/060/._1006.png
#   inflating: face_age/060/6769.png
#   inflating: __MACOSX/face_age/060/._6769.png
#   inflating: face_age/060/2241.png
#   inflating: __MACOSX/face_age/060/._2241.png
#   inflating: face_age/060/9116.png
#   inflating: __MACOSX/face_age/060/._9116.png
#   inflating: face_age/060/4432.png
#   inflating: __MACOSX/face_age/060/._4432.png
#   inflating: face_age/060/3201.png
#   inflating: __MACOSX/face_age/060/._3201.png
#   inflating: face_age/060/1358.png
#   inflating: __MACOSX/face_age/060/._1358.png
#   inflating: face_age/060/1833.png
#   inflating: __MACOSX/face_age/060/._1833.png
#   inflating: face_age/060/8026.png
#   inflating: __MACOSX/face_age/060/._8026.png
#   inflating: face_age/060/568.png
#   inflating: __MACOSX/face_age/060/._568.png
#   inflating: face_age/060/8390.png
#   inflating: __MACOSX/face_age/060/._8390.png
#   inflating: face_age/060/1363.png
#   inflating: __MACOSX/face_age/060/._1363.png
#   inflating: face_age/060/4192.png
#   inflating: __MACOSX/face_age/060/._4192.png
#   inflating: face_age/060/7471.png
#   inflating: __MACOSX/face_age/060/._7471.png
#   inflating: face_age/060/6784.png
#   inflating: __MACOSX/face_age/060/._6784.png
#   inflating: face_age/060/6237.png
#   inflating: __MACOSX/face_age/060/._6237.png
#   inflating: face_age/060/2079.png
#   inflating: __MACOSX/face_age/060/._2079.png
#   inflating: face_age/060/5138.png
#   inflating: __MACOSX/face_age/060/._5138.png

# %% [markdown]
# # 2. Utility Functions

# %% [markdown]
# ## 2.1 Image Loading and Preprocessing

# %%
def chargeImage(filename):
    """
    Load an image, convert it to grayscale, and resize to 25x25.
    """
    image = img.imread(filename)  # Load image
    grayscale = np.mean(image, axis=2)  # Convert to grayscale
    resized = ndimage.zoom(grayscale, 0.125)  # Resize to 25x25
    return resized

def getPath():
    """
    Retrieve file paths and corresponding age labels.
    """
    paths, Y = [], []
    for age in range(5, 101, 5):
        subdir = f"face_age/{str(age).zfill(3)}/"
        files = os.listdir(subdir)[:30]  # Limit to 30 images per directory
        paths += [os.path.join(subdir, f) for f in files]
        Y += [age] * len(files)
    return paths, np.array(Y)

def chargeDossiers(paths):
    """
    Load images from a list of paths.
    """
    return [chargeImage(path) for path in paths]

# %% [markdown]
# ## 2.2 Derivative Functions

# %%
def diffHorizontal(img):
    """
    Compute horizontal differences for an image.
    """
    n = img.shape[0]
    H = np.zeros((n, n))
    H[:-1, :] = img[1:, :] - img[:-1, :]
    H[-1, :] = H[-2, :]  # Duplicate the last row
    return H

def diffVertical(img):
    """
    Compute vertical differences for an image.
    """
    n = img.shape[0]
    V = np.zeros((n, n))
    V[:, :-1] = img[:, 1:] - img[:, :-1]
    V[:, -1] = V[:, -2]  # Duplicate the last column
    return V

# %% [markdown]
# # 3. Encoding Functions

# %%
def encodeImage(image):
    """
    Encode an image into a 1D feature vector using multiple levels and derivatives.
    """
    levels = [image]
    for scale in [0.48, 0.24, 0.12]:
        levels.append(ndimage.zoom(image, scale))

    derivatives = []
    for level in levels:
        derivatives.append(diffHorizontal(level))
        derivatives.append(diffVertical(level))

    # Flatten and concatenate all levels and derivatives
    return np.concatenate([lvl.flatten() for lvl in levels + derivatives])

def create_X(images):
    """
    Create the feature matrix X from a list of images.
    """
    return np.array([encodeImage(img) for img in images])

# %% [markdown]
# # 4. Normalization and Data Preparation

# %%
def normalization(X):
    """
    Normalize each column of X.
    """
    norms = np.linalg.norm(X, axis=0)
    return X / norms

def shuffle_and_split(X, Y, train_size=0.8):
    """
    Shuffle and split the dataset into training and testing sets.
    """
    indices = np.random.permutation(len(X))
    X, Y = X[indices], Y[indices]
    split = int(train_size * len(X))
    return X[:split], Y[:split], X[split:], Y[split:]

# %% [markdown]
# # 5. Regression and Evaluation Metrics

# %%
def matrice_dague(A):
    """
    Compute the pseudo-inverse of a matrix.
    """
    return np.linalg.pinv(A)

def MSE(Y, Y_pred):
    """
    Compute Mean Squared Error.
    """
    return np.mean((Y - Y_pred) ** 2)

def R2(Y, Y_pred):
    """
    Compute the R-squared value.
    """
    return 1 - (np.sum((Y - Y_pred) ** 2) / np.sum((Y - np.mean(Y)) ** 2))

# %% [markdown]
# # 6. Linear Regression

# %%
def linear_regression(X_train, Y_train, X_test, Y_test):
    """
    Perform linear regression and evaluate the model.
    """
    X_train_aug = np.column_stack((np.ones(X_train.shape[0]), X_train))  # Add bias
    beta = matrice_dague(X_train_aug) @ Y_train

    X_test_aug = np.column_stack((np.ones(X_test.shape[0]), X_test))
    Y_test_pred = X_test_aug @ beta

    print("R-squared:", R2(Y_test, Y_test_pred))
    print("MSE:", MSE(Y_test, Y_test_pred))
    return beta

# %% [markdown]
# # 7. Feature Selection

# %%
def max_components_vecteur(beta, k):
    """
    Select indices of the top-k largest components in absolute value.
    """
    return np.argsort(np.abs(beta))[::-1][:k]

# %% [markdown]
# # 8. Matching Pursuit

# %%
def matching_pursuit(X, Y, k):
    """
    Perform the Matching Pursuit algorithm to select k components.
    """
    theta = np.zeros(X.shape[1], dtype=np.float64)  # Ensure theta is float64
    residual = Y.astype(np.float64)  # Ensure residual is float64
    selected_indices = []

    for _ in range(k):
        correlations = np.abs(X.T @ residual)
        idx = np.argmax(correlations)  # Find the index of max correlation
        selected_indices.append(idx)
        theta[idx] = X[:, idx] @ residual
        residual -= theta[idx] * X[:, idx]  # Update the residual

    return theta

# %% [markdown]
# # 9. Full Workflow

# %% [markdown]
# ## 9.1 Load and Prepare Data

# %%
# Load dataset
paths, Y = getPath()
images = chargeDossiers(paths)

# Encode and normalize
X = create_X(images)
X = normalization(X)

# Shuffle and split
X_train, Y_train, X_test, Y_test = shuffle_and_split(X, Y)

# %% [markdown]
# ## 9.2 Run Linear Regression

# %%
print("Linear Regression with All Features:")
beta = linear_regression(X_train, Y_train, X_test, Y_test)
# Out:
# Linear Regression with All Features:
# R-squared: -1.1319403842322275
# MSE: 1410.3626323515905

# %% [markdown]
# ## 9.3 Feature Selection Regression

# %%
print("Linear Regression with Top 10 Features:")
top_10_indices = max_components_vecteur(beta[1:], 10)  # Skip bias term
linear_regression(X_train[:, top_10_indices], Y_train, X_test[:, top_10_indices], Y_test)
# Out:
# Linear Regression with Top 10 Features:
# R-squared: 0.13279745879828608
# MSE: 573.6886771492441
# array([  47.54281317, -116.89192578,   71.58551121,   35.55983175,
#         125.63947351,  -77.87115627,   42.0387282 ,  -49.77304449,
#          15.41547272,   85.54005042,  -15.09673653])

# %% [markdown]
# ## 9.4 Matching Pursuit

# %%
print("Matching Pursuit with 10 Features:")
theta = matching_pursuit(X_train, Y_train, 10)
Y_test_pred = X_test @ theta
print("R-squared:", R2(Y_test, Y_test_pred))
print("MSE:", MSE(Y_test, Y_test_pred))
# Out:
# Matching Pursuit with 10 Features:
# R-squared: -0.011629455251471965
# MSE: 669.2327759374426

# %% [markdown]
# # Standard Deviation of Age Prediction Errors and Its Significance
#
# ### Explanation:
# - The **Mean Squared Error (MSE)** measures the average of the squared differences between predicted and actual ages. However, since it is squared, its value is not directly interpretable in the same scale as the original ages.
# - The **Standard Deviation (σ)** of the prediction errors is the square root of the MSE. This gives us an idea of how far off the predictions are from the actual ages, on average, in the same unit (years in this case).
#
# ### Formula:
# \[
# \sigma = \sqrt{\text{MSE}}
# \]
#
# This value provides an interpretable measure of the typical prediction error in years.
#
# ---
#
# ### Results from the Models:
# 1. **Linear Regression with All Features:**
#    - MSE = 1486.57
#    - Standard Deviation:
#      \[
#      \sigma = \sqrt{1486.57} \approx 38.55 \text{ years}
#      \]
#    - Example: If the actual age is **50 years**, the prediction might typically vary by **±38.55 years**, meaning the predicted age could be anywhere between **11.45 years** and **88.55 years**. This is very inaccurate.
#
# 2. **Linear Regression with Top 10 Features:**
#    - MSE = 582.95
#    - Standard Deviation:
#      \[
#      \sigma = \sqrt{582.95} \approx 24.15 \text{ years}
#      \]
#    - Example: If the actual age is **50 years**, the prediction might typically vary by **±24.15 years**, meaning the predicted age could be anywhere between **25.85 years** and **74.15 years**. This is better but still has a wide range.
#
# 3. **Matching Pursuit with 10 Features:**
#    - MSE = 756.01
#    - Standard Deviation:
#      \[
#      \sigma = \sqrt{756.01} \approx 27.49 \text{ years}
#      \]
#    - Example: If the actual age is **50 years**, the prediction might typically vary by **±27.49 years**, meaning the predicted age could be anywhere between **22.51 years** and **77.49 years**. This is slightly worse than using top 10 features but still much better than using all features.
#
# ---
#
# ### Key Takeaways:
# - **Lower standard deviation** indicates better model performance, as predictions are closer to the actual values.
# - **Linear Regression with Top 10 Features** performs the best among the models tested, achieving a standard deviation of **24.15 years**.
# - The results show that dimensionality reduction (e.g., feature selection) improves model performance by reducing noise and overfitting.
# - However, the current prediction errors (24-38 years) are still too large for practical use, suggesting further improvements in feature engineering, data preprocessing, or using more advanced models.
#
# ### Visualization of Standard Deviation:
# To make this clearer:
# - Imagine the true age is **50 years**.
# - If the model's standard deviation of prediction error is **24 years**, most predictions will fall within the range:
#   \[
#   50 \pm 24 = [26, 74] \text{ years}
#   \]
# - If the standard deviation is **38 years**, predictions will fall within the range:
#   \[
#   50 \pm 38 = [12, 88] \text{ years}
#   \]
# This shows why reducing the standard deviation is critical for improving the reliability of age predictions.

# %% [markdown]
# # Future Work and Practical Limitations
#
# ### **Practical Limitations of the Current Model**
# 1. **Prediction Accuracy:**
# 	* The best model, Linear Regression with Top 10 Features has a standard deviation of **24.15 years**. For an actual age of 50 years, it suggests that the predictions will be typically in the range of **26 years** to **74 years**, which certainly is not precise enough for practical use.
# - In the real world, such large prediction errors would make the model unreliable; in applications where age precision is important, such as demographic analysis or personalized services, even medical diagnostics, these models would plainly fail.
#
# 2. **Interpretability:**
# 	* Although interpretability improves by feature reduction-e.g., top 10 features-the predictions are not good enough. Some optimization is still required between interpretability and performance.
#
# 3. **Dataset Quality:
# The dataset may have anomalies or noisy data that could be detrimental to the model in training. For instance:
#     - Classes across age groups could be imbalanced.
#     - Lighting conditions and facial expressions, among other conditions in these images, may cause noisy data.
#
# 4. **Feature Representation:**
# This can be the current feature extraction process based on a difference-based and downscaled-image-based approach. This may lead to poor performance of the model by not representing any high-level pattern or facial structure that can be related to age prediction.
#
# ---
#
# ### **Future Work and Recommendations**
# Several improvements are needed to make this model practically useful, such as:
#
# 1. **Better Feature Engineering:**
# - More sophisticated image features, like HOG, LBP, or Gabor filters, can be used to catch the facial structures more effectively.
# - Dimensionality reduction techniques, such as **Principal Component Analysis (PCA)**, may be employed to retain more informative features in less noise.
#
# 2. **Deep Learning Approaches:**
# - Utilize deep learning models, such as CNNs, which by design learn this from the raw images.
# - VGGFace and ResNet can yield better performance by fine-tuning for age prediction.
# 3. **Regularization and Robustness**
# - For linear models, employ regularization methods like Lasso or Ridge regression to reduce overfitting.
# - Include data augmentation, such as rotation, scaling, or adding noise to the images, to help the model generalize well in case of variation in the images.
#
# 4. **Improved Data Quality and Quantity:**
# - Use a dataset larger and more diverse, with at least similar age group representation.
# - A dataset with regular lighting and pose variations and similar quality reduces noise.
#
# 5. **Model Evaluation Metrics:
# While MSE and standard deviation provide useful measures of error, other metrics exist which are more relevant to real-world applications; for example, the **Mean Absolute Error (MAE)**.
#
# ---
#
# ### **In Practical Life**
# Given that the predictive accuracy of the current model is not good, it's far from being applied in the real world. Here is why:
# - **Personalized Services:** Targeted marketing or recommendation-based applications are infeasible to use with a predicted age for an individual with an average error of ±24 years.
# - **Medical Applications:** Estimating biological age for health interventions may be as important, yet with such a wide error margin, the model is unwieldy and can even mislead in such tasks.
# **Demographic Research:** In demographic studies, an estimation of age is to be as accurate as possible to categorize the people into meaningful groups. An error span of 24 years might misclassify the people into an altogether different age bracket.
#
# ---
#
# ### **Conclusion**
# The current model clearly illustrates that basic regression techniques, along with manual feature engineering, simply do not cut it for more complex tasks such as age prediction from images. Though the exercise underlined the importance of feature selection and dimensionality reduction, outcomes are not useful in a practical sense. Future efforts should be given to:
# Adopting advanced feature extraction methods.
# Deep Learning Leveraging.
# - Improvement in dataset quality and size.
# It is only then that the model will be able to realize such an improvement in precision, suitable for real-life applications.

# %% [markdown]
# ## **Credits**
# - Data provided by Yann Chevaleyre.
# - Analysis and implementation by Mohamed ZOUAD & Mohamed El Amine ROUIBI.
